# %%
import requests
from datetime import datetime, timedelta

# %%
url = "https://api.coingecko.com/api/v3/simple/price?ids=bitcoin,ethereum&vs_currencies=usd"
response = requests.get(url)
data = response.json()

# %%
data
# Out:
# {'bitcoin': {'usd': 68799}, 'ethereum': {'usd': 2084.22}}

# %%
response = requests.get(url)
data1 = response.json()

# %%
data1
# Out:
# {'bitcoin': {'usd': 68813}, 'ethereum': {'usd': 2084.78}}

# %%
transformed_data = {
        "timestamp": datetime.now().strftime("%Y-%m-%d %H:%M:%S"),
        "bitcoin_price": float(data['bitcoin']['usd']),
        "ethereum_price": float(data['ethereum']['usd'])
    }

# %%
transformed_data
# Out:
# {'timestamp': '2026-03-22 18:18:06',
#  'bitcoin_price': 68799.0,
#  'ethereum_price': 2084.22}
